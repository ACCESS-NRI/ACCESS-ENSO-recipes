# %% [markdown]
# ### Meridional structure of the amplitude of the mean seasonal cycle of PR in the eastern Pacific
#
# Computes the meridional root mean square error (RMSE) of eastern Pacific (15°S-15°N) amplitude (standard deviation) of the mean annual cycle (zonal 150-90°W average) precipitation (PR) between model and observations (the time averaging creates a 12 months mean annual cycle time series from which the standard deviation is computed)
#
# This notebook computes the meridional root mean square error (RMSE) of the amplitude of the mean seasonal cycle of precipitation (PR) between model simulations and observations over the eastern Pacific region (15°S–15°N, 150°W–90°W).
#
# The analysis involves:
#
# - Zonal Averaging: Averaging precipitation data between 150°W and 90°W for both model output and observations.
# - Seasonal Cycle Analysis: Computing the mean annual cycle (12-month time series) at each latitude by averaging monthly precipitation over the analysis period.
# - Amplitude Calculation: Determining the standard deviation of the mean annual cycle at each latitude to quantify its amplitude.
# - Meridional RMSE: Calculating the RMSE between model and observational amplitudes to evaluate the model's ability to replicate the observed seasonal cycle.
#
# ## Observations and reanalysis datasets used for comparison
#
# - **GPCPv2.3 (1979-2018)**: The primary dataset for comparison. The Global Precipitation Climatology Project (GPCP) combines satellite and surface precipitation measurements to provide comprehensive global precipitation data.
#
# These datasets provide a range of perspectives on precipitation patterns, helping to assess the model’s performance more robustly.

# %% [markdown]
# ## Dask Cluster
# Start a cluster with multiple cores

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35451 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:34903' processes=6 threads=24, memory=95.00 GiB>
# 2025-08-08 12:27:42,994 - distributed.nanny - WARNING - Restarting worker

# %%
# ACCESS MOPPeR ESM1.6
import glob
from access_mopper import ACCESS_ESM_CMORiser

ROOT_FOLDER = (
    "/g/data/p73/archive/CMIP7/ACCESS-ESM1-6/spinup/JuneSpinUp-JuneSpinUp-bfaa9c5b/"
)

OUTPUT_FOLDER = "/scratch/iq82/fc6164"

parent_experiment_config = {
    "parent_experiment_id": "piControl",
    "parent_activity_id": "CMIP",
    "parent_source_id": "ACCESS-ESM1-5",
    "parent_variant_label": "r1i1p1f1",
    "parent_time_units": "days since 0001-01-01 00:00:00",
    "parent_mip_era": "CMIP6",
    "branch_time_in_child": 0.0,
    "branch_time_in_parent": 54786.0,
    "branch_method": "standard",
}
# Out:
# Loaded Configuration:
# Creator Name: felicity Chun
# Organisation: ACCESS-NRI
# Creator Email: felicity.chun@anu.edu.au
# Creator URL: 0009-0007-0845-0953

# %%
FILES = glob.glob(ROOT_FOLDER + "output[0-4][0-9][0-9]/atmosphere/netCDF/*mon.nc")
len(FILES)
# Out:
# 6000

# %%
cmoriser = ACCESS_ESM_CMORiser(
    input_paths=FILES,
    compound_name="Amon.pr",
    experiment_id="piControl",
    source_id="ACCESS-ESM1-5",
    variant_label="r1i1p1f1",
    grid_label="gn",
    activity_id="CMIP",
    output_path=OUTPUT_FOLDER,
    parent_info=parent_experiment_config, # <-- This is optional, can be skipped if not needed
    )

# %%
cmoriser.run()

# %%
cmoriser.to_dataset()
# Out:
# <xarray.Dataset> Size: 701MB
# Dimensions:    (lat: 145, time: 6000, bnds: 2, lon: 192)
# Coordinates:
#   * lat        (lat) float64 1kB -90.0 -88.75 -87.5 -86.25 ... 87.5 88.75 90.0
#   * lon        (lon) float64 2kB 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
#   * time       (time) float64 48kB 4.991e+05 4.992e+05 ... 5.739e+05 5.739e+05
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds   (time, lat, bnds) float64 14MB dask.array<chunksize=(1, 145, 2), meta=np.ndarray>
#     lon_bnds   (time, lon, bnds) float64 18MB dask.array<chunksize=(1, 192, 2), meta=np.ndarray>
#     time_bnds  (time, bnds) float64 96kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     pr         (lon, lat, time) float32 668MB dask.array<chunksize=(192, 145, 1), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     creation_date:          2025-08-08T01:59:50Z
#     data_specs_version:     01.00.33
#     experiment:             pre-industrial control
#     experiment_id:          piControl
#     ...                     ...
#     branch_method:          standard
#     external_variables:     areacella
#     creator_name:           felicity Chun
#     creator_organisation:   ACCESS-NRI
#     creator_email:          felicity.chun@anu.edu.au
#     creator_url:            0009-0007-0845-0953

# %%
cmoriser.write()
# Out:
# Exception ignored in: <function CachingFileManager.__del__ at 0x1469e9ae5080>
# Traceback (most recent call last):
#   File "/g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/file_manager.py", line 250, in __del__
#     self.close(needs_lock=False)
#   File "/g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/file_manager.py", line 234, in close
#     file.close()
#   File "src/netCDF4/_netCDF4.pyx", line 2618, in netCDF4._netCDF4.Dataset.close
#   File "src/netCDF4/_netCDF4.pyx", line 2585, in netCDF4._netCDF4.Dataset._close
#   File "src/netCDF4/_netCDF4.pyx", line 2113, in netCDF4._netCDF4._ensure_nc_success
# RuntimeError: NetCDF: Not a valid ID
# 2025-08-08 12:27:42,245 - distributed.worker - WARNING - Compute Failed
# Key:       ('open_dataset-concatenate-81c603ca57fd6f3ce97a43094742f57f', 988, 0)
# Function:  getter
# args:      (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x148585408dc0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None)))))), (slice(0, 1, None), slice(0, 2, None)))
# kwargs:    {}
# Exception: "KeyError('time_bnds')"
#
# 2025-08-08 12:27:42,350 - distributed.worker - WARNING - Compute Failed
# Key:       ('open_dataset-concatenate-81c603ca57fd6f3ce97a43094742f57f', 999, 0)
# Function:  getter
# args:      (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x1485880887c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None)))))), (slice(0, 1, None), slice(0, 2, None)))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# Exception ignored in: <function CachingFileManager.__del__ at 0x1485a59016c0>
# Traceback (most recent call last):
#   File "/g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/file_manager.py", line 250, in __del__
#     self.close(needs_lock=False)
#   File "/g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/file_manager.py", line 234, in close
#     file.close()
#   File "src/netCDF4/_netCDF4.pyx", line 2618, in netCDF4._netCDF4.Dataset.close
#   File "src/netCDF4/_netCDF4.pyx", line 2585, in netCDF4._netCDF4.Dataset._close
#   File "src/netCDF4/_netCDF4.pyx", line 2113, in netCDF4._netCDF4._ensure_nc_success
# RuntimeError: NetCDF: Not a valid ID
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cmoriser.write()
#
# File ~/esmValTool/repos/ACCESS-MOPPeR/src/access_mopper/driver.py:136, in ACCESS_ESM_CMORiser.write(self)
#     132 def write(self):
#     133     """
#     134     Writes the CMORised dataset to the specified output path.
#     135     """
# --> 136     self.cmoriser.write()
#
# File ~/esmValTool/repos/ACCESS-MOPPeR/src/access_mopper/base.py:232, in CMIP6_CMORiser.write(self)
#     230                 if a != "_FillValue":
#     231                     v.setncattr(a, val)
# --> 232         v[:] = vdat.values
#     234 print(f"CMORised output written to {path}")
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/dataarray.py:809, in DataArray.values(self)
#     796 @property
#     797 def values(self) -> np.ndarray:
#     798     """
#     799     The array's data converted to numpy.ndarray.
#     800
#    (...)
#     807     to this array may be reflected in the DataArray as well.
#     808     """
# --> 809     return self.variable.values
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/variable.py:543, in Variable.values(self)
#     540 @property
#     541 def values(self):
#     542     """The variable's data as a numpy.ndarray"""
# --> 543     return _as_array_or_item(self._data)
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/variable.py:341, in _as_array_or_item(data)
#     327 def _as_array_or_item(data):
#     328     """Return the given values as a numpy array, or as an individual item if
#     329     it's a 0d datetime64 or timedelta64 array.
#     330
#    (...)
#     339     TODO: remove this (replace with np.asarray) once these issues are fixed
#     340     """
# --> 341     data = np.asarray(data)
#     342     if data.ndim == 0:
#     343         if data.dtype.kind == "M":
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/dask/array/core.py:1700, in Array.__array__(self, dtype, **kwargs)
#    1699 def __array__(self, dtype=None, **kwargs):
# -> 1700     x = self.compute()
#    1701     if dtype and x.dtype != dtype:
#    1702         x = x.astype(dtype)
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/dask/base.py:379, in DaskMethodsMixin.compute(self, **kwargs)
#     355 def compute(self, **kwargs):
#     356     """Compute this dask collection
#     357
#     358     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     377     dask.compute
#     378     """
# --> 379     (result,) = compute(self, traverse=False, **kwargs)
#     380     return result
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/dask/base.py:665, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     662     postcomputes.append(x.__dask_postcompute__())
#     664 with shorten_traceback():
# --> 665     results = schedule(dsk, keys, **kwargs)
#     667 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/indexing.py:574, in __array__()
#     573 def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
# --> 574     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/indexing.py:577, in get_duck_array()
#     576 def get_duck_array(self):
# --> 577     return self.array.get_duck_array()
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/indexing.py:788, in get_duck_array()
#     787 def get_duck_array(self):
# --> 788     return self.array.get_duck_array()
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/indexing.py:651, in get_duck_array()
#     647     array = apply_indexer(self.array, self.key)
#     648 else:
#     649     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     650     # it may wrap a BackendArray so use its __getitem__
# --> 651     array = self.array[self.key]
#     653 # self.array[self.key] is now a numpy array when
#     654 # self.array is a BackendArray subclass
#     655 # and self.key is BasicIndexer((slice(None, None, None),))
#     656 # so we need the explicit check for ExplicitlyIndexed
#     657 if isinstance(array, ExplicitlyIndexed):
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:100, in __getitem__()
#      99 def __getitem__(self, key):
# --> 100     return indexing.explicit_indexing_adapter(
#     101         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     102     )
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/core/indexing.py:1015, in explicit_indexing_adapter()
#     993 """Support explicit indexing by delegating to a raw indexing method.
#     994
#     995 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1012 Indexing result, in the form of a duck numpy-array.
#    1013 """
#    1014 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1015 result = raw_indexing_method(raw_key.tuple)
#    1016 if numpy_indices.tuple:
#    1017     # index the loaded np.ndarray
#    1018     indexable = NumpyIndexingAdapter(result)
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:112, in _getitem()
#     110 try:
#     111     with self.datastore.lock:
# --> 112         original_array = self.get_array(needs_lock=False)
#     113         array = getitem(original_array, key)
#     114 except IndexError:
#     115     # Catch IndexError in netCDF4 and return a more informative
#     116     # error message.  This is most often called when an unsorted
#     117     # indexer is used before the data is loaded from disk.
#
# File /g/data/tm70/fc6164/conda/envs/esmvaltool_dev/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:92, in get_array()
#      90 def get_array(self, needs_lock=True):
#      91     ds = self.datastore._acquire(needs_lock)
# ---> 92     variable = ds.variables[self.variable_name]
#      93     variable.set_auto_maskandscale(False)
#      94     # only added in netCDF4-python v1.2.8
#
# KeyError: 'time_bnds'

# %%
import xarray as xr
ds = cmoriser.to_dataset()
# d_array = ds.to_dataarray(dim='pr')
# d_array.to_iris()
 5, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 7, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 6, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 9, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 12, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1584, 2, 15, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 12, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 5, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 4, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 6, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 9, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 7, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1199, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 6, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 12, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 5, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 4, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 7, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 9, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1401, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 6, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 5, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 9, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 7, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 12, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 4, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1198, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 6, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 12, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 4, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 7, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 5, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 9, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1161, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 4, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 12, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 9, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 5, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 7, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 6, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1390, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1324, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1324, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1324, 8, 16, 12, 0, 0, 0, has_year_zero=True),
#  cftime.DatetimeProlepticGregorian(1324, 4, 16, 0, 0, 0, 0, has_year_zero=True),
#  ...]

# %%
esm16 = cmoriser.to_iris() #No module named 'iris.experimental.xarray'
from ncdata.iris_xarray import cubes_from_xarray, cubes_to_xarray # install ncdata
# cubes = cubes_from_xarray(dataset)
# xrds = cubes_to_xarray(cubes)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/esmValTool/repos/ACCESS-MOPPeR/src/access_mopper/driver.py:115, in ACCESS_ESM_CMORiser.to_iris(self)
#     114 try:
# --> 115     from iris.experimental.xarray import as_cubes
#     117     return as_cubes(self.cmoriser.ds)
#
# ModuleNotFoundError: No module named 'iris.experimental.xarray'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 esm16 = cmoriser.to_iris() #No module named 'iris.experimental.xarray'
#       2 from ncdata.iris_xarray import cubes_from_xarray, cubes_to_xarray
#       3 # cubes = cubes_from_xarray(dataset)
#       4 # xrds = cubes_to_xarray(cubes)
#
# File ~/esmValTool/repos/ACCESS-MOPPeR/src/access_mopper/driver.py:119, in ACCESS_ESM_CMORiser.to_iris(self)
#     117     return as_cubes(self.cmoriser.ds)
#     118 except ImportError:
# --> 119     raise ImportError(
#     120         "iris and iris.experimental.xarray are required for to_iris(). Please install iris."
#     121     )
#
# ImportError: iris and iris.experimental.xarray are required for to_iris(). Please install iris.

# %% [markdown]
# ## Datasets

# %%
from esmvalcore.dataset import Dataset

# %%
model_datasets = {
"ACCESS-ESM1-5": 
    Dataset(
    short_name='pr',
    project='CMIP6',
    mip="Amon",
    exp="historical",
    ensemble="r1i1p1f1",
    timerange="18500101/20150101",
    dataset="ACCESS-ESM1-5",
    grid="gn"
)}

obs_datasets = {
"GPCP-SG": 
    Dataset(
    short_name='pr',
    dataset='GPCP-SG',
    mip="Amon",
    project='OBS',
    type='atmos',
    timerange="19790101/20190101",
    tier=2),
}

# %% [markdown]
# ## Add Ancillary files

# %%
for name, dataset in model_datasets.items():
    dataset.add_supplementary(short_name='sftlf', mip="fx")
    dataset.add_supplementary(short_name="areacella", mip="fx")

# %%
model_datasets = {name: dataset.load() for name, dataset in model_datasets.items()}
obs_datasets = {name: dataset.load() for name, dataset in obs_datasets.items()}
# Out:
# WARNING:esmvalcore.local:'CMIP6' rootpaths '/g/data/zv30/cmip/CMIP6' set in config-user.yml do not exist
# WARNING:esmvalcore.cmor._fixes.fix.genericfix:Long name changed from 'Percentage of the grid  cell occupied by land (including lakes)' to 'Percentage of the Grid Cell Occupied by Land (Including Lakes)'
# (for file /g/data/fs38/publications/CMIP6/CMIP/CSIRO/ACCESS-ESM1-5/historical/r1i1p1f1/fx/sftlf/gn/v20191115/sftlf_fx_ACCESS-ESM1-5_historical_r1i1p1f1_gn.nc)

# %%
from esmvalcore.preprocessor import zonal_statistics
from esmvalcore.preprocessor import regrid
from esmvalcore.preprocessor import mask_landsea
from esmvalcore.preprocessor import convert_units
from esmvalcore.preprocessor import extract_region
from esmvalcore.preprocessor import extract_time
from esmvalcore.preprocessor import climate_statistics

import iris
import numpy as np

# %%
def preproc1(cube):
    nino3_latext_region = {"start_longitude": 150., "end_longitude": 270., "start_latitude": -15., "end_latitude": 15.}
    cube = extract_time(cube, start_year=1979, start_month=1, start_day=1, end_year=2014, end_month=12, end_day=31)
    cube = mask_landsea(cube, mask_out="land")
    cube = convert_units(cube, units="mm/day")
    cube = climate_statistics(cube, operator="mean", period="monthly")
    cube = regrid(cube, target_grid="1x1", scheme="linear")
    cube = extract_region(cube, **nino3_latext_region)
    cube.coord('month_number').guess_bounds()
    cube = cube.collapsed('month_number', iris.analysis.STD_DEV)
    return cube

def preproc2(cube):
    nino3_latext_region = {"start_longitude": 210., "end_longitude": 270., "start_latitude": -15., "end_latitude": 15.}
    cube = extract_time(cube, start_year=1979, start_month=1, start_day=1, end_year=2014, end_month=12, end_day=31)
    cube = convert_units(cube, units="mm/day")
    cube = mask_landsea(cube, mask_out="land")
    cube = climate_statistics(cube, operator="mean", period="monthly")
    cube = regrid(cube, target_grid="1x1", scheme="linear")
    cube = extract_region(cube, **nino3_latext_region)
    cube.coord('month_number').guess_bounds()
    cube = cube.collapsed('month_number', iris.analysis.STD_DEV)
    cube = zonal_statistics(cube, 'mean')
    
    return cube

# rmse calc from obs
def rmse(obs_cube, model_cube):
    return np.sqrt(np.mean((obs_cube.data - model_cube.data) ** 2))

# %%
model_datasets_prep1 = {name: preproc1(dataset) for name, dataset in model_datasets.items()}
obs_datasets_prep1 = {name: preproc1(dataset) for name, dataset in obs_datasets.items()}

model_datasets_prep2 = {name: preproc2(dataset) for name, dataset in model_datasets.items()}
obs_datasets_prep2 = {name: preproc2(dataset) for name, dataset in obs_datasets.items()}

# %% [markdown]
# ## Diagnostics Level 1

# %%
import iris.quickplot as qplt
import matplotlib.pyplot as plt

#plot 1
def format_latitude(x):
    if x < 0:
        return f'{abs(x)}°S'
    elif x > 0:
        return f'{x}°N'
    else:
        return '0°'

obs_data = obs_datasets_prep2["GPCP-SG"]
model_data = model_datasets_prep2["ACCESS-ESM1-5"]
error = rmse(obs_data, model_data)

qplt.plot(model_data, label='ACCESS-ESM1-5', linewidth=2)
qplt.plot(obs_data, color='black', label='Observation', linewidth=2)

plt.text(0.5, 0.95, f'RMSE: {error:.2f}', fontsize=12, ha='center', transform=plt.gca().transAxes,
         bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
plt.legend()
# ax = plt.gca()
plt.grid(linestyle='--')
plt.title('PR seasonal cycle std')

plt.yticks(np.arange(0,9, step=2))
plt.ylabel('PR std (mm/day)')

xt = np.arange(-10,15,step=10)
xlab = [format_latitude(x) for x in xt]
plt.xticks(xt,xlab)
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# Figure 1: Meridional bias in the amplitude of the mean seasonal precipitation cycle (PR) in the eastern Pacific (averaged between 150–90°W). The black curve represents the reference data, while the blue curve represents the model data. The metric shown is the meridional RMSE between the model and reference curves.

# %% [markdown]
# ## Diagnostics level 2

# %%
import iris.plot as iplt
import matplotlib.colors as mcolors
import cartopy.feature as cfeature
import cartopy.crs as ccrs

fig = plt.figure(figsize=(20, 7))
proj = ccrs.Orthographic(central_longitude=210.0)
i =121
process = {**model_datasets_prep1, **obs_datasets_prep1}


for label, cube in process.items():
    
    ax1 = plt.subplot(i,projection=proj)
    ax1.add_feature(cfeature.LAND, facecolor='gray')  # Add land feature with gray color
    ax1.coastlines()
    cf1 = iplt.contourf(cube, levels=np.arange(0,10,0.2), cmap='Reds')

    ax1.set_extent([130, 290, -20, 20], crs=ccrs.PlateCarree())
    ax1.set_title(label)

    # Add gridlines for latitude and longitude
    gl1 = ax1.gridlines(draw_labels=True, linestyle='--')
    gl1.top_labels = False
    gl1.right_labels = False

    i+=1


# Add a single colorbar at the bottom
cax = plt.axes([0.15,0.08,0.7,0.05])
cbar = fig.colorbar(cf1, cax=cax, orientation='horizontal', extend='both', ticks=np.arange(0,10,1))
cbar.set_label('PR std ')

# %% [markdown]
# Figure 2: Bias in the amplitude of the mean seasonal cycle of precipitation (PR) in the equatorial Pacific. The left map shows the reference data, while the right map displays the model data.

# %% [markdown]
# # Diagnostic level 3
#
# The third level shows the meridional structure of the mean seasonal cycle in a Hovmöller diagram

# %%
def preproc3(cube):
    nino3_latext_region = {"start_longitude": 210., "end_longitude": 270., "start_latitude": -15., "end_latitude": 15.}
    cube = convert_units(cube, units="mm/day")
    cube = mask_landsea(cube, mask_out="land")
    cube = climate_statistics(cube, operator="mean", period="monthly")
    cube = regrid(cube, target_grid="1x1", scheme="linear")
    cube = extract_region(cube, **nino3_latext_region)
    cube = zonal_statistics(cube, operator='mean')
    
    return cube

model_datasets_prep3 = {name: preproc3(dataset) for name, dataset in model_datasets.items()}
obs_datasets_prep3 = {name: preproc3(dataset) for name, dataset in obs_datasets.items()}
process = {**model_datasets_prep3, **obs_datasets_prep3}

# %%
fig = plt.figure(figsize=(10, 6))
i=121

# Define tick positions and labels for the y-axis (months)
month_ticks = np.arange(1, 13, 4)
month_labels =['Jan', 'May', 'Sep'] 
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                # 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

axls =[]
for label, cube in process.items():
    
    ax1 = plt.subplot(i)
    cf1 = iplt.contourf(cube,coords=['latitude','month_number'],levels=np.arange(0,20.5,0.5),cmap="viridis")
    ax1.set_ylim(1, 12)
    ax1.set_yticks(ticks=month_ticks, labels=month_labels)
    ax1.set_title(label)
    ax1.set_ylabel("months")
    ax1.set_xlabel("latitude")
    axls.append(ax1)
    i+=1

# Add a single colorbar at the bottom
cbar = fig.colorbar(cf1, ax=axls, orientation='horizontal',shrink=0.8, extend='both')
cbar.set_label('PR (mm/day)')

# %% [markdown]
# Figure 3: Meridional structure of the mean seasonal cycle of precipitation (PR) in the eastern Pacific (averaged between 150–90°W). The left map represents the reference data, while the right map shows the model data.
